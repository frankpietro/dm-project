# %% [markdown]
# # Data Mining Project
# ### Giorgio Donati, g.donati24@studenti.unipi.it
# ### Pietro Francaviglia, p.francaviglia1@studenti.unipi.it
# #### A.Y. 2021-2022

# %% [markdown]
# # Libraries and datasets

# %%
import math
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

from col_names import *
from utility import *

# %% [markdown]
# # Clustering

# %%
with open(f'{PICKLE_FOLDER}basket_prepared_df.pkl', 'rb') as f:
    b_df = pickle.load(f)
with open(f'{PICKLE_FOLDER}item_prepared_df.pkl', 'rb') as f:
    i_df = pickle.load(f)
with open(f'{PICKLE_FOLDER}user_prepared_df.pkl', 'rb') as f:
    u_df = pickle.load(f)
with open(f'{PICKLE_FOLDER}shop_prepared_df.pkl', 'rb') as f:
    s_df = pickle.load(f)
with open(f'{PICKLE_FOLDER}date_prepared_df.pkl', 'rb') as f:
    d_df = pickle.load(f)

# %%
with open(f'{PICKLE_FOLDER}pure_basket_prepared_df.pkl', 'rb') as f:
    pure_b_df = pickle.load(f)
with open(f'{PICKLE_FOLDER}pure_item_prepared_df.pkl', 'rb') as f:
    pure_i_df = pickle.load(f)
with open(f'{PICKLE_FOLDER}pure_user_prepared_df.pkl', 'rb') as f:
    pure_u_df = pickle.load(f)
with open(f'{PICKLE_FOLDER}pure_shop_prepared_df.pkl', 'rb') as f:
    pure_s_df = pickle.load(f)
with open(f'{PICKLE_FOLDER}pure_date_prepared_df.pkl', 'rb') as f:
    pure_d_df = pickle.load(f)

# %% [markdown]
# ## Shop rankings

# %%
s_df[APR] = rankings(s_df[PAVG])
s_df[ABR] = rankings(s_df[BCNT])
s_df[ACR] = rankings(s_df[CCNT])
s_df[AIR] = rankings(s_df[ICNT])

# %%
pure_s_df[APR] = rankings(pure_s_df[PAVG])
pure_s_df[ABR] = rankings(pure_s_df[BCNT])
pure_s_df[ACR] = rankings(pure_s_df[CCNT])
pure_s_df[AIR] = rankings(pure_s_df[ICNT])

# %%
s_df
# Out:
#          shop_id   total_price  item_count  item_dist_count  basket_count  \
# shop_id
# 0              0  9.450283e+05        1620             1030            64
# 1              1  5.665487e+05         949              708            53
# 2              2  5.542179e+06        4198             2255           713
# 3              3  4.379351e+06        4291             2517           712
# 4              4  6.258392e+06        7365             3837           866
# 5              5  4.861004e+06        5891             3361           755
# 6              6  1.290391e+07       14540             7182          1045
# 7              7  1.106885e+07       12212             5700          1050
# 8              8  5.632032e+05         859              709            80
# 9              9  1.295119e+07       12533             2056           129
# 10            10  2.450692e+06        3090             1995           648
# 11            11  7.248909e+05         796              629            77
# 12            12  1.376352e+07        8394             3004           611
# 13            13  7.559666e+05        2710             1901           432
# 14            14  6.342916e+06        7025             3446           794
# 23                   33   701.683148                     2
# 24                   57  1035.008484                     3
# 25                   66   849.059899                     2
# 26                   60   924.823675                     3
# 27                   63   951.334625                     3
# 28                   61   818.706153                     2
# 29                   55   934.003866                     3
# 30                   56   700.724134                     2
# 31                   61   710.716936                     2
# 32                   50   700.257559                     2
# 33                   41   937.321702                     3
# 34                   42  1311.692404                     5
# 35                   63   951.736338                     3
# 37                   58   880.876625                     3
# 38                   58  1114.859082                     4
# 39                   48   961.468534                     3
# 40                   19   903.211574                     3
# 41                   57   854.786878                     2
# 42                   60   930.023208                     3
# 43                   60  1154.279491                     4
# 44                   58   687.233582                     2
# 45                   58   925.382922                     3
# 46                   56   889.108287                     3
# 47                   51  1055.396980                     3
# 48                   48  1047.408549                     3
# 49                   59  1154.585658                     4
# 50                   54   943.312920                     3
# 51                   51   484.966647                     1
# 52                   56   838.434081                     2
# 53                   64   845.037906                     2
# 54                   65   714.559777                     2
# 55                   10   710.449649                     2
# 56                   59   693.902130                     2
# 57                   60   829.112705                     2
# 58                   58   811.851932                     2
# 59                   53   890.382084                     3
#
#         average_basket_ranking average_category_ranking average_item_ranking
# shop_id
# 0                            0                        3                    0
# 1                            0                        3                    0
# 2                            3                        5                    0
# 3                            3                        5                    0
# 4                            4                        5                    1
# 5                            3                        5                    0
# 6                            5                        6                    2
# 7                            5                        6                    1
# 8                            0                        3                    0
# 9                            0                        5                    1
# 10                           3                        5                    0
# 11                           0                        4                    0
# 12                           3                        6                    1
# 13                           2                        2                    0
# 14                           4                        5                    1
# 15                           4                        5                    1
# 16                           4                        6                    1
# 17                           2                        5                    0
# 18                           4                        6                    1
# 19                           5                        6                    1
# 20                           0                        4                    0
# 21                           4                        5                    1
# 22                           4                        5                    1
# 23                           0                        2                    0
# 24                           4                        5                    1
# 25                           6                        6                    5
# 26                           5                        6                    1
# 27                           5                        6                    3
# 28                           6                        6                    4
# 29                           4                        5                    1
# 30                           3                        5                    1
# 31                           6                        6                    6
# 32                           0                        4                    0
# 33                           0                        3                    0
# 34                           0                        3                    0
# 35                           5                        6                    1
# 37                           4                        5                    1
# 38                           4                        5                    1
# 39                           1                        4                    0
# 40                           0                        1                    0
# 41                           4                        5                    1
# 42                           5                        6                    3
# 43                           3                        6                    1
# 44                           4                        5                    0
# 45                           4                        5                    0
# 46                           5                        5                    1
# 47                           4                        5                    1
# 48                           2                        4                    0
# 49                           2                        6                    0
# 50                           4                        5                    1
# 51                           4                        5                    1
# 52                           4                        5                    0
# 53                           5                        6                    1
# 54                           5                        6                    4
# 55                           3                        0                    1
# 56                           5                        6                    1
# 57                           5                        6                    3
# 58                           4                        5                    1
# 59                           4                        5                    0
