# %% [markdown]
# # Data Mining Project
# ### Giorgio Donati, g.donati24@studenti.unipi.it
# ### Pietro Francaviglia, p.francaviglia1@studenti.unipi.it
# #### A.Y. 2021-2022

# %% [markdown]
# # Libraries and datasets

# %%
import math
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

from col_names import *
from utility import *

# %% [markdown]
# # Clustering

# %%
with open(f'{PICKLE_FOLDER}basket_prepared_df.pkl', 'rb') as f:
    b_df = pickle.load(f)
with open(f'{PICKLE_FOLDER}item_prepared_df.pkl', 'rb') as f:
    i_df = pickle.load(f)
with open(f'{PICKLE_FOLDER}user_prepared_df.pkl', 'rb') as f:
    u_df = pickle.load(f)
with open(f'{PICKLE_FOLDER}shop_prepared_df.pkl', 'rb') as f:
    s_df = pickle.load(f)
with open(f'{PICKLE_FOLDER}date_prepared_df.pkl', 'rb') as f:
    d_df = pickle.load(f)

# %% [markdown]
# ## Shop rankings

# %%
s_df[APR] = rankings(s_df[PAVG])
loghist(s_df[APR], 'shop price rankings distribution')

# %%
s_df[ABR] = rankings(s_df[BCNT])
loghist(s_df[ABR], 'basket count rankings distribution')

# %%
s_df[ACR] = rankings(s_df[CCNT])
loghist(s_df[ACR], 'category count rankings, distribution')

# %%
s_df[AIR] = rankings(s_df[ICNT])
loghist(s_df[AIR], 'category count rankings, distribution')
